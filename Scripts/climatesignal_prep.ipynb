# %%
from netCDF4 import Dataset

dat = Dataset('C:/Users/PfitznerD/Desktop/Studium/WS20_21/Angew.Sys2/Gruppenprojekt/Austria.projections/rr_rcp85_rel-ccs_2071-2100--1971-2000_annual.nc')
#dat.variables['y'][:]
#dat.variables['x'][:]

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# setup Lambert Conformal basemap.
m = Basemap(width=500000,height=500000,projection='lcc',
            resolution='c',lat_1=49,lat_2=47.5,lat_0=46,lon_0=13.33)
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
m.drawcountries()
# draw parallels and meridians.
# label parallels on right and top
# meridians on bottom and left
parallels = np.arange(0.,81,1.)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(1.,351.,2.)
m.drawmeridians(meridians,labels=[True,False,False,True])
# plot blue dot on Boulder, colorado and label it as such.
#lon, lat = 13.494360329155962, 46.7237601056795 # Location of Stockenboi
lon, lat = 15.440278, 47.101944 # Location of Stufenbach
# convert to map projection coords.
# Note that lon,lat can be scalars, lists or numpy arrays.
xpt,ypt = m(lon,lat)
# convert back to lat/lon
lonpt, latpt = m(xpt,ypt,inverse=True)
m.plot(xpt,ypt,'bo')  # plot a blue dot there
# put some text next to the dot, offset a little bit
# (the offset is in map projection coordinates)
plt.text(xpt+15000,ypt-9000,'Stockenboi (%1.1fW,%1.1fN)' % (lonpt,latpt))
plt.title('Lambert conformal conic projection of Stokenboi')
plt.show()

print("projection_x_coordinate:", "{:.2f}".format(xpt), "meters")
print("projection_y_coordinate:", "{:.2f}".format(ypt), "meters")
# Out:
# projection_x_coordinate: 409724.89 meters
# projection_y_coordinate: 374769.96 meters

# %%
#dat

# %%
import xarray


data_an = xarray.open_dataset('C:/Users/PfitznerD/Desktop/Studium/WS20_21/Angew.Sys2/Gruppenprojekt/Austria.projections/rr_rcp85_rel-ccs_2071-2100--1971-2000_annual.nc')

q50_an = data_an.q50
q10_an = data_an.q10
q90_an = data_an.q90

y_an = data_an.variables['y'][:]
x_an = data_an.variables['x'][:]

a_an = q50_an.sel(y = y_an[99:100],x = x_an[298:299]).mean(dim=('x','y')) 
b_an = q10_an.sel(y = y_an[99:100],x = x_an[298:299]).mean(dim=('x','y')) 
c_an = q90_an.sel(y = y_an[99:100],x = x_an[298:299]).mean(dim=('x','y')) 



data_djf = xarray.open_dataset('C:/Users/PfitznerD/Desktop/Studium/WS20_21/Angew.Sys2/Gruppenprojekt/Austria.projections/rr_rcp85_rel-ccs_2071-2100--1971-2000_djf.nc')

q50_djf = data_djf.q50
q10_djf = data_djf.q10
q90_djf = data_djf.q90

y_djf = data_djf.variables['y'][:]
x_djf = data_djf.variables['x'][:]

a_djf = q50_djf.sel(y = y_djf[99:100],x = x_djf[298:299]).mean(dim=('x','y')) 
b_djf = q10_djf.sel(y = y_djf[99:100],x = x_djf[298:299]).mean(dim=('x','y')) 
c_djf = q90_djf.sel(y = y_djf[99:100],x = x_djf[298:299]).mean(dim=('x','y')) 


data_mam = xarray.open_dataset('C:/Users/PfitznerD/Desktop/Studium/WS20_21/Angew.Sys2/Gruppenprojekt/Austria.projections/rr_rcp85_rel-ccs_2071-2100--1971-2000_mam.nc')

q50_mam = data_mam.q50
q10_mam = data_mam.q10
q90_mam = data_mam.q90

y_mam = data_mam.variables['y'][:]
x_mam = data_mam.variables['x'][:]

a_mam = q50_mam.sel(y = y_mam[99:100],x = x_mam[298:299]).mean(dim=('x','y')) 
b_mam = q10_mam.sel(y = y_mam[99:100],x = x_mam[298:299]).mean(dim=('x','y')) 
c_mam = q90_mam.sel(y = y_mam[99:100],x = x_mam[298:299]).mean(dim=('x','y')) 



data_jja = xarray.open_dataset('C:/Users/PfitznerD/Desktop/Studium/WS20_21/Angew.Sys2/Gruppenprojekt/Austria.projections/rr_rcp85_rel-ccs_2071-2100--1971-2000_jja.nc')

q50_jja = data_jja.q50
q10_jja = data_jja.q10
q90_jja = data_jja.q90

y_jja = data_jja.variables['y'][:]
x_jja = data_jja.variables['x'][:]

a_jja = q50_jja.sel(y = y_jja[99:100],x = x_jja[298:299]).mean(dim=('x','y')) 
b_jja = q10_jja.sel(y = y_jja[99:100],x = x_jja[298:299]).mean(dim=('x','y')) 
c_jja = q90_jja.sel(y = y_jja[99:100],x = x_jja[298:299]).mean(dim=('x','y'))  


data_son = xarray.open_dataset('C:/Users/PfitznerD/Desktop/Studium/WS20_21/Angew.Sys2/Gruppenprojekt/Austria.projections/rr_rcp85_rel-ccs_2071-2100--1971-2000_son.nc')

q50_son = data_son.q50
q10_son = data_son.q10
q90_son = data_son.q90

y_son = data_son.variables['y'][:]
x_son = data_son.variables['x'][:]

a_son = q50_son.sel(y = y_son[99:100],x = x_son[298:299]).mean(dim=('x','y')) 
b_son = q10_son.sel(y = y_son[99:100],x = x_son[298:299]).mean(dim=('x','y')) 
c_son = q90_son.sel(y = y_son[99:100],x = x_son[298:299]).mean(dim=('x','y'))

# %%
x = ['Jährlich','DJF','MAM', 'JJA', 'SON']

y = [float(a_an),float(a_djf), float(a_mam), float(a_jja), float(a_son)]
yerrormin = [abs(float(b_an))+float(a_an),float(a_djf)-abs(float(b_djf)),float(a_mam)-abs(float(b_mam)),abs(float(b_jja))+float(a_jja),abs(float(b_son))+float(a_son)]
yerrormax = [abs(float(c_an))-float(a_an),abs(float(c_djf))-float(a_djf),abs(float(c_mam))-float(a_mam),abs(float(c_jja))-float(a_jja),abs(float(c_son))-float(a_son)]


yerror = [yerrormin, yerrormax]

plt.plot(x,y,'o')

plt.errorbar(x,y,yerr=yerror, fmt='o', ecolor='darkblue', elinewidth=2, capsize=10,label='q50, q10, q90 Perzentil',
             capthick=2, barsabove=False, errorevery=1, alpha=1, ms=10)
plt.legend()

 
#plt.title('Relatives Climate Change Signal 2071-2100 -- 1971-2000\n des Niederschlags unter dem RCP8.5 Szenario für den Stufenbach')
plt.ylabel('NS-Änderung [%]')

plt.plot()
plt.savefig('projection')

# %%
b_son
# Out:
# <xarray.DataArray 'q10' ()>
# array(-8.32403779)

# %%
z = data_an.variables['x'][:]
z
# Out:
# <xarray.IndexVariable 'x' (x: 575)>
# array([111500, 112500, 113500, ..., 683500, 684500, 685500])
# Attributes:
#     axis:           X
#     units:          meters
#     standard_name:  projection_x_coordinate
